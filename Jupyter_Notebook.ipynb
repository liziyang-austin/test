# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Final Assignment

# %% [markdown]
# ## Introduction
# This notebook covers various aspects of data science including languages, libraries, and tools.

# %% [markdown]
# ## Data Science Libraries
# - Pandas (Python)
# - NumPy (Python)
# - SciPy (Python)
# - ggplot2 (R)
# - dplyr (R)

# %% [markdown]
# ## Data Science Tools
# | Tool | Description |
# | ---- | ----------- |
# | Jupyter Notebook | Interactive computing environment |
# | RStudio | IDE for R |
# | Apache Spark | Unified analytics engine |
# | Tableau | Data visualization tool |

# %% [markdown]
# ## Arithmetic Expression Examples
# In programming, arithmetic expressions include operations like addition (+), subtraction (-), multiplication (*), and division (/).

# %% [markdown]
# # Arithmetic operations

# %%
a = 10
b = 5
print("Addition:", a + b)
print("Multiplication:", a * b)
# Out:
# Addition: 15
# Multiplication: 50

# %% [markdown]
# # Convert minutes to hours

# %%
minutes = 120
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 120 minutes is equal to 2.0 hours.

# %% [markdown]
# ## Objectives
# - Understand basic data science concepts
# - Learn the usage of different data science tools
# - Explore various data science libraries and languages

# %% [markdown]
# ## Author
# Li Ziyang
